# %%
from matplotlib import pyplot as plt

from data_handler import TrainDataHandler
from exploratory_data_analysis import (
    plot_class_distribution, 
    plot_gene_distribution,
    interesting_genes,
    plot_text_length_distribution,
    plot_text_char_length_distribution,
    plot_unique_genes_distribution,
    plot_word_cloud,
)


TRAIN_VARIANTS_PATH = "../data/training_variants/training_variants"
TRAIN_TEXT_PATH = "../data/training_text/training_text"


# Reflect changes in the modules immediately.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_data_handler = TrainDataHandler(TRAIN_VARIANTS_PATH, TRAIN_TEXT_PATH)
# Out:
# 2022-12-16 18:50:44 | DEBUG    | data_handler         | Loading the train variants data..
# 2022-12-16 18:50:44 | DEBUG    | data_handler         | Loading the train text data..
# 2022-12-16 18:50:45 | DEBUG    | data_handler         | Preparing train data ..
# 2022-12-16 18:50:45 | INFO     | data_handler         | Train data is loaded. (Data size: (3316, 5))

# %%
train_data_handler.train_data.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 Text
# 0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   Abstract Background  Non-small cell lung canc...
# 2   Abstract Background  Non-small cell lung canc...
# 3  Recent evidence has demonstrated that acquired...
# 4  Oncogenic mutations in the monomeric Casitas B...

# %%
plot_class_distribution(train_data_handler.train_data, class_names=True)
plt.savefig("img/ClassDistributionTrainData.png", format="png", bbox_inches='tight', dpi=600)

# %%
plot_gene_distribution(train_data_handler.train_data, top_n=25)
plt.savefig("img/GeneDistributionTrainData.png", format="png", bbox_inches='tight', dpi=600)

# %%
interesting_genes_4 = ["BRCA1", "TP53", "EGFR", "PTEN"]

interesting_genes(train_data_handler.train_data, interesting_genes_4)
# Out:
# BRCA1 is observed as Likely Neutral 90 times out of 264 observations.
# Likely Neutral             90
# Likely Loss-of-function    60
# Inconclusive               53
# Loss-of-function           46
# Neutral                    15
# Name: Class, dtype: int64
#
# TP53 is observed as Likely Loss-of-function 83 times out of 163 observations.
# Likely Loss-of-function    83
# Loss-of-function           67
# Inconclusive                5
# Likely Gain-of-function     3
# Likely Neutral              2
# Neutral                     2
# Switch-of-function          1
# Name: Class, dtype: int64
#
# EGFR is observed as Gain-of-function 84 times out of 141 observations.
# Gain-of-function             84
# Likely Gain-of-function      45
# Loss-of-function              5
# Likely Neutral                3
# Inconclusive                  1
# Neutral                       1
# Likely Switch-of-function     1
# Likely Loss-of-function       1
# Name: Class, dtype: int64
#
# ...

# %%
plot_text_length_distribution(train_data_handler.train_data)
plt.savefig("img/TextLengthDistributionTrainData.png", format="png", bbox_inches='tight', dpi=600)

# %%
plot_text_char_length_distribution(train_data_handler.train_data)
plt.savefig("img/TextLengthDistributionBoxPlotTrainData.png", format="png", bbox_inches='tight', dpi=600)

# %%
plot_unique_genes_distribution(train_data_handler.train_data)
plt.savefig("img/UniqueGenesDistributionTrainData.png", format="png", bbox_inches='tight', dpi=600)

# %%
plot_word_cloud(train_data_handler.train_data)
plt.savefig("img/WordCloudTrainData.png", format="png", bbox_inches='tight', dpi=1200)
# Out:
# 2022-12-16 22:25:06 | DEBUG    | exploratory_data_analysis | Class 1 plotted.
# 2022-12-16 22:25:26 | DEBUG    | exploratory_data_analysis | Class 2 plotted.
# 2022-12-16 22:25:30 | DEBUG    | exploratory_data_analysis | Class 3 plotted.
# 2022-12-16 22:25:57 | DEBUG    | exploratory_data_analysis | Class 4 plotted.
# 2022-12-16 22:26:04 | DEBUG    | exploratory_data_analysis | Class 5 plotted.
# 2022-12-16 22:26:12 | DEBUG    | exploratory_data_analysis | Class 6 plotted.
# 2022-12-16 22:26:53 | DEBUG    | exploratory_data_analysis | Class 7 plotted.
# 2022-12-16 22:26:55 | DEBUG    | exploratory_data_analysis | Class 8 plotted.
# 2022-12-16 22:26:58 | DEBUG    | exploratory_data_analysis | Class 9 plotted.

# %%
train_data_handler.train_data[train_data_handler.train_data["Class"] == 8].shape
# Out:
# (19, 5)
