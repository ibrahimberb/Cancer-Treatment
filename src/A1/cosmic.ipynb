# %%
import pandas

COSMIC_DATA_PATH = "../../data/cosmic/Census_allSat Dec 17 05_17_35 2022.csv"

cosmic_data = pandas.read_csv(COSMIC_DATA_PATH)
cosmic_data
# Out:
#     Gene Symbol                                               Name  \
# 0          ABI1                                   abl-interactor 1
# 1          ABL1  v-abl Abelson murine leukemia viral oncogene h...
# 2          ABL2     c-abl oncogene 2, non-receptor tyrosine kinase
# 3         ACKR3                      atypical chemokine receptor 3
# 4         ACSL3     acyl-CoA synthetase long-chain family member 3
# ..          ...                                                ...
# 573       ZMYM2                            zinc finger protein 198
# 574      ZNF331                            zinc finger protein 331
# 575      ZNF384                 zinc finger protein 384 (CIZ/NMP4)
# 576      ZNF521                            zinc finger protein 521
# 577       ZRSR2  zinc finger (CCCH type), RNA-binding motif and...
#
#      Entrez GeneId        Genome Location  Tier Hallmark  Chr Band Somatic  \
# 0            10006   10:26746593-26860935     1      Yes     12.10     yes
# ...
